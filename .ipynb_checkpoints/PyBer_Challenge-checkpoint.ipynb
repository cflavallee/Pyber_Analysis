# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import os

# File to Load (Remember to change these)
city_data_to_load = os.path.join("Resources", "city_data.csv")
ride_data_to_load = os.path.join("Resources", "ride_data.csv")

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head(200)
# Out:
#                    city             date   fare        ride_id  driver_count  \
# 0    Lake Jonathanshire  1/14/2019 10:14  13.83  5739410935873             5
# 1    South Michelleport   3/4/2019 18:24  30.24  2343912425577            72
# 2    Port Samanthamouth   2/24/2019 4:29  33.44  2005065760003            57
# 3            Rodneyfort  2/10/2019 23:22  23.44  5149245426178            34
# 4            South Jack    3/6/2019 4:28  34.58  3908451377344            46
# ..                  ...              ...    ...            ...           ...
# 195      New Jacobville  1/15/2019 15:27  27.24  3812959891670            50
# 196  Lake Jonathanshire   1/2/2019 14:14  13.89   424254840012             5
# 197  Port Samanthamouth   4/25/2019 9:50  25.50  1169125626263            57
# 198          West Heidi   3/26/2019 9:45  22.33   826311164930            28
# 199           Karenside   4/14/2019 5:11  13.13  3659608833762             5
#
#       type
# 0    Urban
# 1    Urban
# 2    Urban
# 3    Urban
# 4    Urban
# ..     ...
# 195  Urban
# 196  Urban
# 197  Urban
# 198  Urban
# 199  Urban
#
# [200 rows x 6 columns]

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
ride_count_total = pyber_data_df.groupby(["type"]).count()["ride_id"]

ride_count_total
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
driver_count_total = city_data_df.groupby(["type"]).sum()["driver_count"]

driver_count_total
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
fare_count_total = pyber_data_df.groupby(["type"]).sum()["fare"]

fare_count_total
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
fare_type_average = pyber_data_df.groupby(["type"]).mean()["fare"]

fare_type_average
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: fare, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
per_driver_fare_type = fare_count_total / driver_count_total
# per_driver_fare_type

per_driver_fare_type
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

pyber_summary_df = pd.DataFrame(
                                {"Total Rides" : ride_count_total,
                                  "Total Drivers" : driver_count_total,
                                  "Total Fares" :fare_count_total,
                                  "Average Fare per Ride" : fare_type_average,
                                  "Average Fare per Driver" : per_driver_fare_type
                                 })



pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)
pyber_summary_df
# Out:
#           Total Rides  Total Drivers Total Fares Average Fare per Ride  \
# Rural             125             78   $4,327.93                $34.62
# Suburban          625            490  $19,356.33                $30.97
# Urban            1625           2405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head()
# Out:
#                  city             date   fare        ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5739410935873             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2343912425577            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2005065760003            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5149245426178            34
# 4          South Jack    3/6/2019 4:28  34.58  3908451377344            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
fares_by_date_df = pyber_data_df.groupby(["type","date"]).sum()[["fare"]]

fares_by_date_df
# Out:
#                         fare
# type  date
# Rural 1/1/2019 9:45    43.69
#       1/11/2019 4:39   16.42
#       1/14/2019 15:58  54.10
#       1/14/2019 7:09   18.05
#       1/15/2019 21:44  30.26
# ...                      ...
# Urban 5/8/2019 1:54    32.69
#       5/8/2019 2:31    41.33
#       5/8/2019 4:20    21.99
#       5/8/2019 4:39    18.45
#       5/8/2019 7:29    18.55
#
# [2364 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
fares_by_date_df = fares_by_date_df.reset_index()
fares_by_date_df
# Out:
#        type             date   fare
# 0     Rural    1/1/2019 9:45  43.69
# 1     Rural   1/11/2019 4:39  16.42
# 2     Rural  1/14/2019 15:58  54.10
# 3     Rural   1/14/2019 7:09  18.05
# 4     Rural  1/15/2019 21:44  30.26
# ...     ...              ...    ...
# 2359  Urban    5/8/2019 1:54  32.69
# 2360  Urban    5/8/2019 2:31  41.33
# 2361  Urban    5/8/2019 4:20  21.99
# 2362  Urban    5/8/2019 4:39  18.45
# 2363  Urban    5/8/2019 7:29  18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
fares_by_date_df.pivot(index="date", columns="type", values="fare")
# Out:
# type            Rural  Suburban  Urban
# date
# 1/1/2019 0:08     NaN       NaN  37.91
# 1/1/2019 0:46     NaN     47.74    NaN
# 1/1/2019 12:32    NaN     25.56    NaN
# 1/1/2019 14:40    NaN       NaN   5.42
# 1/1/2019 14:42    NaN       NaN  12.31
# ...               ...       ...    ...
# 5/8/2019 1:54     NaN       NaN  32.69
# 5/8/2019 2:31     NaN       NaN  41.33
# 5/8/2019 4:20     NaN       NaN  21.99
# 5/8/2019 4:39     NaN       NaN  18.45
# 5/8/2019 7:29     NaN       NaN  18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
fares_by_jan_apr_df = fares_by_date_df.loc[(fares_by_date_df["date"] >= "1/1/2019") & (fares_by_date_df["date"] < "4/30/2019")]

fares_by_jan_apr_df
# Out:
#        type             date   fare
# 0     Rural    1/1/2019 9:45  43.69
# 1     Rural   1/11/2019 4:39  16.42
# 2     Rural  1/14/2019 15:58  54.10
# 3     Rural   1/14/2019 7:09  18.05
# 4     Rural  1/15/2019 21:44  30.26
# ...     ...              ...    ...
# 2191  Urban    4/3/2019 3:36  43.07
# 2192  Urban    4/3/2019 7:02  29.88
# 2193  Urban    4/3/2019 7:51  32.70
# 2194  Urban    4/3/2019 8:47   4.74
# 2195  Urban    4/3/2019 9:30   5.16
#
# [2105 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
fares_by_jan_apr_df.index = pd.to_datetime(fares_by_jan_apr_df.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
